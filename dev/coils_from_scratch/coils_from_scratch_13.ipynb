# %% [markdown]
# # Building coilsPy from scratch

# %% [markdown]
# ## Step 1: Normalized Generation Scheme
# First we need a reliable way of generating a tensor of complex numbers that sum to be some specified point along the complex unit circle. To help, let's use a simple function to plot out complex tensors tip-to-tail to ensure they meet this criteria.

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_complex_vectors(complex_array):
    # Plot the unit circle
    angles = np.linspace(0, 2 * np.pi, 100)
    plt.plot(np.cos(angles), np.sin(angles), linestyle='dotted')

    # Starting point for the vectors
    start = 0 + 0j
    for z in complex_array:
        # Plot each vector
        end = start + z
        plt.arrow(start.real, start.imag, z.real, z.imag,
                  head_width=0.05, head_length=0.05, length_includes_head=True)
        start = end

    # Set equal scaling and labels
    plt.axis('equal')
    plt.xlabel('Real')
    plt.ylabel('Imaginary')
    plt.grid(True)
    plt.title('Complex Vectors Summation')

    # Show the plot
    plt.show()

# %% [markdown]
# ## Create Kernels
#
# For creating dirichlet distributions we will introduce some kernel options.

# %% [markdown]
# There are a number of ways I can accomplish our needs, but currently I am using the following approach:

# %%
import torch

def generate_rbf(length, center_index, sigma):
    """
    Generates a 1D radial basis function (Gaussian) of specified width centered on a given index.

    Parameters:
    length (int): The length of the output tensor.
    center_index (int): The index at which the RBF is centered.
    sigma (float): The standard deviation (width) of the RBF.

    Returns:
    torch.Tensor: A 1D tensor representing the radial basis function.
    """
    if center_index >= length or center_index < 0:
        raise ValueError("Center index must be within the range of the tensor length.")

    # Create an array of indices
    x = torch.arange(0, length, dtype=torch.float32)

    # Calculate the RBF
    rbf = torch.exp(-0.5 * ((x - center_index) / sigma) ** 2)

    return rbf

def generate_kernel(length, center_index, type = "rbf", restrictions = [], **kwargs):
    if type == "rbf":
        kernel = generate_rbf(length, center_index, kwargs['sigma'])
        
    # Replace zero values with min_value
    kernel = torch.where(kernel == 0, torch.tensor(1e-10, dtype=kernel.dtype), kernel)
    
    # Set restrictions to 0
    kernel[restrictions] = 1e-10
    
    return kernel


# Example usage
length = 10  # Length of the tensor
center_index = 5  # Center the RBF at index 5
sigma = 1  # Standard deviation of the RBF

rbf_tensor = generate_kernel(length, center_index, type = "rbf", sigma=sigma)

# Plotting the RBF
plt.scatter(torch.arange(length), rbf_tensor)
plt.title("Radial Basis Function (RBF)")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %%
def rescale_array_to_target_torch(tensor, target_sum):
    # Create a mask for non-zero elements
    non_zero_mask = tensor > 1e-5

    # Calculate the sum of non-zero elements
    sum_non_zero = torch.sum(tensor[non_zero_mask])

    # Count the non-zero elements
    count_non_zero = torch.sum(non_zero_mask)
    
    # Avoid division by zero in case all elements are zero
    if count_non_zero == 0:
        return tensor

    # Calculate the required adjustment to reach the target sum
    adjustment = (target_sum - sum_non_zero) / count_non_zero
    
    # Add the adjustment to each non-zero element
    tensor[non_zero_mask] += adjustment

    return tensor

# %%
torch.distributions.Dirichlet(torch.tensor([5.1, 0.5])).sample()
# Out:
# tensor([0.8682, 0.1318])

# %%
import torch

def dirichlet_to_goal(goal_value, num_elements, center_index, sigma, magnitude, restrictions):
    # Generate alphas for dirichlet
    alphas = generate_kernel(length = num_elements, center_index = center_index, type = "rbf", sigma = sigma, restrictions = restrictions) * magnitude
    rand_samples = torch.distributions.Dirichlet(alphas).sample()
    
    rand_samples = rescale_array_to_target_torch(rand_samples, goal_value)
    
    return rand_samples

def generate_complex_sum(goal_theta, num_elements, center_index_re, center_index_im, sigma_re, sigma_im, magnitude_re, magnitude_im, restrictions = []):
    real_goal = torch.cos(goal_theta)
    imag_goal = torch.sin(goal_theta)
    real_parts = dirichlet_to_goal(1, num_elements, center_index_re, sigma_re, magnitude_re, restrictions)
    imag_parts = dirichlet_to_goal(0, num_elements, center_index_im, sigma_im, magnitude_im, restrictions)
    complex_numbers = torch.complex(real_parts, imag_parts)
    
    # Step 4: Rotate the entire set of vectors by the goal theta
    rotated_complex_numbers = complex_numbers * (real_goal + imag_goal * 1j)
    
    rotated_complex_numbers = torch.tensor(rotated_complex_numbers, dtype=torch.complex128)

    return rotated_complex_numbers

# Example usage
theta = torch.tensor([0.3 * torch.pi])  # 90 degrees, should sum to i
complex_array = generate_complex_sum(theta, 
                                     num_elements = 5, 
                                     center_index_re = 0, 
                                     center_index_im = 0, 
                                     sigma_re = 1e100, 
                                     sigma_im = 1e100, 
                                     magnitude_re = 1, 
                                     magnitude_im = 1,
                                     restrictions = [])
plot_complex_vectors(complex_array.numpy())
# Out:
# C:\Users\johnm\AppData\Local\Temp\ipykernel_15932\2512545771.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rotated_complex_numbers = torch.tensor(rotated_complex_numbers, dtype=torch.complex128)

# %%
dirichlet_to_goal(0, num_elements = 4, center_index=0, sigma=100, magnitude = 1, restrictions = [1,2,3])
# Out:
# tensor([0.0000e+00, 1.1755e-38, 1.1755e-38, 1.1755e-38])

# %% [markdown]
# ## Renormalization
#
# In theory, the previous steps should ensure conservation. However, even when using a precision of complex128, there are still memory errors that cause us to lose conservation. Therefore we can optionally renormalize.

# %%
def renormalize_to_unit_circle(array):
    """
    Renormalizes an array of complex numbers so that it sums to a point on the unit circle.

    Parameters:
    array (torch.Tensor): A 1D tensor of complex numbers.

    Returns:
    torch.Tensor: A renormalized 1D tensor of complex numbers.
    """
    current_sum = torch.sum(array)
    if current_sum == 0:
        return array  # Avoid division by zero if the current sum is 0

    # Calculate the magnitude of the current sum
    magnitude = torch.abs(current_sum)

    # Calculate the scale factor
    scale_factor = 1 / magnitude

    # Renormalize the array
    renormalized_array = array * scale_factor

    return renormalized_array

# %% [markdown]
# ## Initial State Generation
#
# This function alone is sufficient for generating our initial state, so let's make some helper functions to generate our initial transition tensor and interaction tensor.

# %%
# Transition tensor create:
def initialize_transition_tensor(num_elements, theta, restrict_dict = []):
    # Create a list to store each column
    columns = []
    num_columns = num_elements

    for col in range(num_columns):
        
        if col in restrict_dict:
            restrictions = restrict_dict[col]
        else:
            restrictions = []
                    
        column = generate_complex_sum(theta, 
                    num_elements = num_elements, 
                    center_index_re = col, 
                    center_index_im = 0, 
                    sigma_re = torch.rand(1)[0]*0.3 + 0.2, 
                    sigma_im = 1e10, 
                    magnitude_re = 1.0, 
                    magnitude_im = 1e5,
                    restrictions = restrictions)
        columns.append(column.unsqueeze(1))  # Add a dimension to make it a column

    # Combine columns into a matrix
    transition_tensor = torch.cat(columns, dim=1)
    
    return transition_tensor

# %%
# Interaction Tensor Create:
def initialize_interaction_tensor(num_elements, theta, restrict_dict = []):
    # Example usage
    num_3d_tensors = num_elements + 1  # Number of 3D tensors in the 4D tensor
    num_matrices = num_elements  # Number of 2D matrices in each 3D tensor
    num_columns = num_elements  # Number of columns in each 2D matrix

    # Create a list to store each 3D tensor
    tensors_3d = []

    for _ in range(num_3d_tensors):
        matrices = []
        for _ in range(num_matrices):
            columns = []
            for col in range(num_columns):
                
                if col in restrict_dict:
                    restrictions = restrict_dict[col]
                else:
                    restrictions = []
                    
                column = generate_complex_sum(theta, 
                                    num_elements = num_elements, 
                                    center_index_re = col, 
                                    center_index_im = 0, 
                                    sigma_re = torch.rand(1)[0]*0.3 + 0.2, 
                                    sigma_im = 1e10, 
                                    magnitude_re = 1.0, 
                                    magnitude_im = 1e5,
                                    restrictions = restrictions)
                columns.append(column.unsqueeze(1))  # Add a dimension to make it a column
            matrix = torch.cat(columns, dim=1)
            matrices.append(matrix)  # Add a dimension to make it a 2D matrix
        tensor_3d = torch.stack(matrices, dim=2)
        tensors_3d.append(tensor_3d)

    # Combine 3D tensors into a 4D tensor
    # Stack along the fourth dimension
    interaction_tensor = torch.stack(tensors_3d, dim=3)
    
    return interaction_tensor

# %% [markdown]
# Now we can generate all the starting states:

# %%
num_elements = 5

# Thetas for state, transition, and interactions
angles_dict = {
    'state': 0.3,
    'transition': 0.2,
    'interaction': 0.4
}

# Set restrictions

# Local
# restrict_dict = {
#     0: [2, 3, 4],
#     1: [3, 4],
#     2: [0, 4],
#     3: [0, 1],
#     4: [0, 1, 2]
# }

# Grouping
# restrict_dict = {
#     0: [2, 3, 4],
#     1: [2, 3, 4],
#     2: [0, 1],
#     3: [0, 1],
#     4: [0, 1]
# }

# No restrictions
restrict_dict = {}

thetas_dict = {key : torch.tensor([value * torch.pi]) for key, value in angles_dict.items()}

# Establish state_tensor
state_tensor = generate_complex_sum(thetas_dict['state'], 
                                     num_elements = num_elements, 
                                     center_index_re = 0, 
                                     center_index_im = 0, 
                                     sigma_re = 1e100, 
                                     sigma_im = 1e100, 
                                     magnitude_re = 1, 
                                     magnitude_im = 100,
                                     restrictions = [])
transition_tensor = initialize_transition_tensor(theta = thetas_dict['transition'], num_elements = num_elements, restrict_dict=restrict_dict)
interaction_tensor = initialize_interaction_tensor(theta = thetas_dict['interaction'], num_elements = num_elements, restrict_dict=restrict_dict)

# Move everything to GPU
state_tensor = state_tensor.to('cuda:0')
transition_tensor = transition_tensor.to('cuda:0')
interaction_tensor = interaction_tensor.to('cuda:0')

state_tensor.device
# Out:
# C:\Users\johnm\AppData\Local\Temp\ipykernel_15932\2512545771.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rotated_complex_numbers = torch.tensor(rotated_complex_numbers, dtype=torch.complex128)
# device(type='cuda', index=0)

# %%
abs(transition_tensor)
# Out:
# tensor([[9.9792e-01, 5.9751e-04, 4.8158e-04, 9.3669e-04, 2.7621e-04],
#         [2.1005e-03, 9.9968e-01, 3.1367e-05, 1.3497e-04, 2.1526e-04],
#         [4.5381e-04, 5.6207e-05, 1.0000e+00, 4.4554e-05, 1.9154e-04],
#         [6.8820e-04, 1.1461e-03, 4.4763e-05, 1.0000e+00, 3.1893e-04],
#         [5.6602e-04, 7.3458e-04, 6.6292e-04, 1.1398e-03, 1.0000e+00]],
#        device='cuda:0', dtype=torch.float64)

# %%
subvec = state_tensor[0] + state_tensor[1]
subvec * torch.conj(subvec)
# Out:
# tensor(0.1039+0.j, device='cuda:0', dtype=torch.complex128)

# %%
print("CUDA GPU:", torch.cuda.is_available())
# Out:
# CUDA GPU: True

# %% [markdown]
# ## Normalization testing
# Let's first do some quick tests to make sure our normalization is working as intended

# %%
# First just checking that our initial transition tensor looks good:
new_state_tensor = torch.matmul(transition_tensor,state_tensor)

plot_complex_vectors(new_state_tensor.to('cpu').numpy())

# %%
# Now we check that our interaction tensor works as intended
sel_state = 1

if sel_state == 0:
    selected_normalized_tensor = state_tensor
else:
    selected_normalized_tensor = transition_tensor[:,sel_state-1]
    
selected_interaction_tensor = interaction_tensor[:,:,:,sel_state]

new_transition_tensor = torch.matmul(selected_interaction_tensor, selected_normalized_tensor)

print(new_transition_tensor)

new_state_tensor = torch.matmul(new_transition_tensor, state_tensor)

plot_complex_vectors(new_state_tensor.to('cpu').numpy())
# Out:
# tensor([[-3.0772e-01+9.5027e-01j,  3.4746e-04+1.1349e-04j,
#          -7.4345e-05-2.3878e-05j,  6.3192e-04+2.0523e-04j,
#          -1.9980e-05-6.6207e-06j],
#         [ 2.6211e-04+1.2998e-03j, -3.0965e-01+9.5085e-01j,
#           9.1451e-04+2.9840e-04j,  7.2298e-04+2.3546e-04j,
#          -1.2524e-06-1.3542e-06j],
#         [ 3.2091e-05+8.9000e-06j,  8.7444e-05+2.8236e-05j,
#          -3.1020e-01+9.5067e-01j, -4.2249e-04+2.1923e-04j,
#           1.4372e-04+4.6856e-05j],
#         [-3.2776e-04-1.0620e-04j,  7.0661e-04+2.3099e-04j,
#           7.3863e-04+2.4115e-04j, -2.9898e-01+9.1982e-01j,
#          -3.0210e-04+5.1773e-04j],
#         [-1.2681e-03-4.1245e-04j, -5.0377e-04-1.6418e-04j,
#          -3.9920e-04-1.3083e-04j, -1.0965e-02+3.0577e-02j,
#          -3.0884e-01+9.5050e-01j]], device='cuda:0', dtype=torch.complex128)

# %%
check = torch.matmul(selected_interaction_tensor, selected_normalized_tensor)[:,1]
sum(check * torch.conj(sum(check)))
# Out:
# tensor(1.0000+5.3126e-18j, device='cuda:0', dtype=torch.complex128)

# %%
check = selected_interaction_tensor[:,:,1]
sum(check * torch.conj(sum(check)))
# Out:
# tensor([1.0000+8.6736e-19j, 1.0000-2.4395e-17j, 1.0000+0.0000e+00j,
#         1.0000+1.3254e-17j, 1.0000+2.4937e-18j], device='cuda:0',
#        dtype=torch.complex128)

# %%
def complex_add(tensor):
    return torch.abs(torch.real(tensor)+torch.imag(tensor))

complex_add(torch.complex(torch.tensor([5.0, 3.0]), torch.tensor([-2.0, 2.0])))
# Out:
# tensor([3., 5.])

# %% [markdown]
# Now that this is workign as intended, let's make our function to select the normalized subgroup and associated transition matrix that will maximize the probability from going from the largest state to the smallest state.

# %%
def select_transition_tensor(state_tensor,transition_tensor,interaction_tensor, use_abs = False):
    if use_abs:
        sum_select = torch.abs
    else:
        sum_select = complex_add
    
    # First we need to know which transition point we are looking for
    state_magnitudes = sum_select(state_tensor)
    state_magnitudes_order = torch.argsort(state_magnitudes)
    to_index = state_magnitudes_order[0] # The smallest state magnitude
    from_index = state_magnitudes_order[-1] # The largest state magnitude
    
    # Next we need to go through each possible normalized subgroup and determine which one we should use
    new_transitions = []
    for sel_state in range(state_tensor.shape[0]):
        if sel_state == 0:
            selected_normalized_tensor = state_tensor
        else:
            selected_normalized_tensor = transition_tensor[:,sel_state-1]
            
        selected_interaction_tensor = interaction_tensor[:,:,:,sel_state]

        new_transition_tensor = torch.matmul(selected_interaction_tensor,selected_normalized_tensor)
        
        new_transitions.append(new_transition_tensor)
        
     # Convert list of tensors to a tensor
    new_transitions_tensor = torch.stack(new_transitions)
    
    sorted_indices = torch.argsort(sum_select(new_transitions_tensor[:, to_index, from_index]), descending=True)
    selected_subgroup = sorted_indices[0]
    
    return new_transitions[selected_subgroup], selected_subgroup

select_transition_tensor(state_tensor,transition_tensor,interaction_tensor)
# Out:
# (tensor([[-3.0964e-01+9.5084e-01j,  5.0506e-04+1.6390e-04j,
#           -1.4146e-03-4.5934e-04j,  1.0177e-03+3.3137e-04j,
#            8.4040e-05+2.8420e-05j],
#          [ 8.3101e-04+2.8020e-04j, -3.0882e-01+9.5112e-01j,
#            5.8728e-04+3.1714e-04j,  6.2171e-04+2.0342e-04j,
#            6.0700e-04+1.9655e-04j],
#          [-4.0743e-04-1.3302e-04j,  2.7015e-04+8.7408e-05j,
#           -3.0981e-01+9.5051e-01j, -7.3273e-03+1.7226e-02j,
#           -4.7391e-04-1.5601e-04j],
#          [ 3.3819e-04+1.1051e-04j, -8.3128e-04-2.6906e-04j,
#           -2.6074e-04+7.4464e-05j, -3.0256e-01+9.3355e-01j,
#           -4.6204e-04-1.4928e-04j],
#          [-1.3378e-04-4.4185e-05j, -1.3882e-04-4.5507e-05j,
#            1.8842e-03+6.1273e-04j, -7.6990e-04-2.5225e-04j,
#           -3.0877e-01+9.5114e-01j]], device='cuda:0', dtype=torch.complex128),
#  tensor(2, device='cuda:0'))

# %% [markdown]
# Finally we just need to step through the coil

# %%
import time

tic = time.time()

num_steps = 10_00
prob_save = []

# Load tensors
# state_tensor = torch.load('../saved_tensors/state_tensor_20240328_phaseshift.pt')
# transition_tensor = torch.load('../saved_tensors/transition_tensor_20240328_phaseshift.pt')
# interaction_tensor = torch.load('../saved_tensors/interaction_tensor_20240328_phaseshift.pt')

starting_state_tensor = state_tensor
starting_transition_tensor = transition_tensor

print(f"substate starting total: {sum(torch.real(state_tensor * torch.conj(state_tensor.sum()))[:2])}")
for i_step in range(num_steps):
    transition_tensor, selected_subgroup = select_transition_tensor(state_tensor,transition_tensor,interaction_tensor, use_abs = False)
    
    #print(sum(transition_tensor[:,3] * torch.conj(transition_tensor[:,3].sum())))
    
    state_tensor = torch.matmul(transition_tensor,state_tensor)
    
    #plot_complex_vectors(state_tensor.to('cpu').numpy())
    
    # Optionally we can renomalize to avoid memory errors
    state_tensor = renormalize_to_unit_circle(state_tensor)
    
    state_prob = torch.real(state_tensor * torch.conj(state_tensor.sum()))
    
    prob_save.append(state_prob)
    
    #print(state_prob[0]+state_prob[1])
    #print(state_prob.sum())
    # print(selected_subgroup)
    
    #plot_complex_vectors(state_tensor.to('cpu').numpy())
    
toc = time.time()    
print(f"substate ending total: {sum(torch.real(state_tensor * torch.conj(state_tensor.sum()))[:2])}")

print(f"Processing time: {round(toc-tic,4)}s")
print(state_prob.sum())
# Out:
# substate starting total: 0.3206318602622936
# tensor(1.0000+3.7080e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.2884e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.8489e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3878e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.7278e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1633e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.6729e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8323e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3151e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.5670e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6671e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.8254e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4420e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2118e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4449e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3553e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.9197e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4752e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.7604e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1200e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3017e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8865e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.0365e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.0249e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6346e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.1583e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.0683e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1276e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0300e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5912e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3180e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.7578e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.6379e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2201e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.2118e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.8189e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5045e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.2125e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3661e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4528e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2418e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.8905e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1167e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.3936e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1333e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.1608e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3017e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7405e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2251e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.2143e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.8381e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.9573e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.4402e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.2016e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.6494e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.3643e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.5919e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1442e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.9765e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.5779e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2143e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.3936e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3769e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.5728e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.2642e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4286e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6563e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4095e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1117e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.8789e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1384e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.9255e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.1232e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.3827e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.3502e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.9273e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2768e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5287e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8974e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.0817e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.7578e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.1716e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9407e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3010e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4586e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.9414e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9273e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.7412e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.1557e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.5511e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.6678e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.8305e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.1283e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4803e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.6621e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.5128e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1417e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8757e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4882e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1250e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.1933e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.2143e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7105e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7781e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0571e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.8164e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.1800e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.9870e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.4994e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.0365e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8974e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7347e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3010e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.8496e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.6494e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.4810e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4095e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2526e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7322e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7322e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6046e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1142e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.8731e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3227e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8865e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5052e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9082e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.2251e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.8814e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2418e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.7680e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7756e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4210e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9624e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.1557e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.7221e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.5894e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6263e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1442e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.5732e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9949e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.2335e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1959e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4102e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.6494e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.8905e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.0817e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.2826e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5804e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.6621e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.2175e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.9873e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4937e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.9873e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.4181e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5070e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0817e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2660e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.9273e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5153e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4745e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.7839e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6046e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0058e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4210e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7947e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.8905e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.5345e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0831e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3986e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4095e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3527e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.4893e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1493e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.2884e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.5052e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4937e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6455e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.2233e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.3068e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.2157e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1059e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.1716e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2143e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8974e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.5410e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7105e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6021e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.6379e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.9899e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2768e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6588e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.8598e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9382e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.4568e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5804e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1876e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.4702e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1767e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1167e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7756e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.0715e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2743e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.8572e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9165e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.5887e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1876e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.1800e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6046e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.8572e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4210e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.9147e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5912e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1876e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.0683e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6263e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8106e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3310e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4503e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4210e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7756e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7347e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.5536e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3094e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2634e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7972e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6563e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.8572e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.8905e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.4810e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.4593e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.3050e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6646e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7756e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2701e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.9389e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7456e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7972e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.0141e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1633e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.6079e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7347e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.4994e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3661e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.6812e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2360e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3878e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.2042e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.5052e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.9848e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1200e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.3827e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.2042e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9787e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.0715e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6046e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.3726e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6563e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1276e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7130e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3769e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4395e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6100e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0517e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5233e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3039e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0354e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.8547e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.9389e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0408e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.6946e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.1637e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.7004e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.5970e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1200e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1709e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3636e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3824e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.1120e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1225e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0001-3.5779e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7972e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3473e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.5652e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8189e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.8905e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.5627e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1276e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.1073e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.9960e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.6621e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.2330e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.2399e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3986e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.6379e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7105e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2973e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.0531e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6643e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0115e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7947e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1850e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8406e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6480e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.2746e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.9584e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3961e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.5894e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.2884e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2577e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8540e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3585e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3852e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0192e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.8438e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7972e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7972e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.5938e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1008e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.7105e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6914e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.7463e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.2067e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1059e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.7839e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.9899e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7271e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1709e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.8247e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1872e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5587e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1225e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.0231e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3010e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7998e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.8362e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4286e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.5103e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1659e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4532e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.9873e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1901e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.8120e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.4886e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.9284e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3581e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8623e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.0600e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.0524e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8623e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.4235e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.7578e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9624e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.1557e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7922e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9707e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0115e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8431e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3010e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.3827e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.7680e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.7278e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.7578e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.2175e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.5894e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.0575e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8974e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3473e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.4185e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.9797e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.2584e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.5894e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4745e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.8120e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1926e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.9389e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.8063e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2226e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.2577e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.9747e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.4568e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6563e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.6404e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9707e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4694e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4427e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.0715e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6238e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4311e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.8279e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8919e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.2985e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.9873e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8189e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.8955e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3260e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7347e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8215e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.0231e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2360e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4745e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.2447e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.0766e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6914e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5269e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1413e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0658e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1034e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1926e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.8681e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.9465e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.2042e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3010e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1984e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.8623e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0734e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5587e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3151e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5153e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4095e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.8193e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.0141e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1467e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.8623e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3636e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5696e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.0520e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5721e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5858e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1384e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4745e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.6187e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.1800e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4232e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1250e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.2450e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.8406e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1005e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.0231e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.4402e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.6379e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.2475e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1467e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.5703e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3910e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9949e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.6350e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.9899e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1633e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3878e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1388e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.7683e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.9989e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2092e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3162e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4528e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7239e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.4937e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.9873e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1034e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0625e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3527e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1666e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4528e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6263e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.5074e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.7221e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3227e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.8738e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8865e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.1117e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5587e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0192e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5587e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.8355e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0192e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.8305e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8189e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.2042e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1850e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8919e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.0231e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6888e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4911e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4962e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1276e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.7578e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.1557e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1225e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.9899e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.5613e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.3827e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.0141e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0083e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6021e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4745e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.9873e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5052e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1467e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.7896e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.0256e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.9631e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.6324e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6863e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1384e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.1200e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5396e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7889e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7054e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.2284e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.9273e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8865e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0864e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1742e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4311e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3661e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.2768e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.0173e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.7036e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3668e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0925e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.5894e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8106e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.2399e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.5613e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4528e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6321e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.5218e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3444e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.8547e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0166e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.2833e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3010e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.0173e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.9223e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1200e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5587e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.7578e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.9682e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.0358e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6700e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9057e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.0090e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0600e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.5536e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.5894e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1200e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1034e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0061e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.0600e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.3610e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3776e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.8572e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.9165e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7405e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0929e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.5103e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.0227e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8052e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7730e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.6107e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.3317e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.5894e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6321e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5153e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0712e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.0715e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.9631e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.6079e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8648e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3419e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7347e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.0600e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.2042e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1901e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1276e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5153e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1117e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.1315e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.0036e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9732e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9949e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6859e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2526e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3885e-17j, device='cuda:0', dtype=torch.complex128)
# ...
# tensor(1.0000-1.9190e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.8547e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.8547e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6941e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3227e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9624e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.1315e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.1850e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.5410e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2143e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.9740e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2035e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3010e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.6892e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.8063e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.0958e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.7604e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7130e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.6480e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.8464e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3010e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.1800e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0452e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.0473e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2797e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.3177e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1926e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.6379e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.9147e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.9848e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6021e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1493e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.7036e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8215e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.7947e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.2067e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7297e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.7756e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.0715e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.1980e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.1315e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.9389e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.0065e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5829e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5052e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.0817e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.7271e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.5786e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.3068e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7022e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.2092e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8540e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.4778e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4095e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1142e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.7195e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.5536e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5052e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6021e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3010e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.4478e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.9747e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.2042e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.8977e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0408e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5052e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.2143e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6263e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.8027e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4203e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9545e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.2941e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8865e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0983e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.0524e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2009e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.0520e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1059e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6209e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.1008e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.4908e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.4311e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4210e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0842e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1926e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4720e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.9490e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.0231e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.5262e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.7029e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4937e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4210e-20j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5179e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5052e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.5001e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.0498e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4532e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.9631e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.3426e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7351e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+0.j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.9465e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3010e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.2526e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5533e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.9490e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3419e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0148e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.9006e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.6162e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.0043e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.6021e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4720e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9082e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1792e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.1315e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.5996e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.9031e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.0799e-16j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9082e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7510e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1709e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.8381e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.6480e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.7405e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7080e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.5652e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.5562e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.5020e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7347e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.9060e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4210e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4720e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.9899e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.3343e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.2042e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.1315e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.2450e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.6494e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.5952e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7401e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.2551e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4286e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.2768e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6321e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.3310e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.8088e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.8547e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7705e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.6863e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6021e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.9747e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.0842e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.5836e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.2501e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.5587e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.7578e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.4810e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9353e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.3010e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.0011e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.8865e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.6021e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.3368e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.3878e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.2360e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.5070e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-4.3368e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.6212e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.0224e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7347e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.5703e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.1196e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9516e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.9338e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.6787e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.8247e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4752e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-6.1257e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9516e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+3.4694e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.5396e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0058e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.8764e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4644e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-7.4810e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.7347e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.0817e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.4991e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-9.1615e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.2606e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.1124e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+9.9855e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.1709e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+5.4210e-20j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.9082e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.1684e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+7.8063e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.6736e-19j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.0032e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-3.7947e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+6.8088e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-1.8215e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.4698e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+2.8623e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.9841e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+8.8905e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+1.7130e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000+4.7705e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-2.3419e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.3126e-18j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-8.0881e-17j, device='cuda:0', dtype=torch.complex128)
# tensor(1.0000-5.6162e-17j, device='cuda:0', dtype=torch.complex128)
# substate ending total: 0.45195851958394295
# Processing time: 4.5326s
# tensor(1.0000, device='cuda:0', dtype=torch.float64)

# %%
# Your data
data = [row.to('cpu') for row in prob_save]
# Transpose the data to get 5 traces
traces = list(zip(*data))

# Plotting
plt.figure(figsize=(10, 6))
for i, trace in enumerate(traces):
    plt.plot(trace, label=f'Trace {i+1}')

plt.xlabel('Timestep')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
print(state_tensor)
# Out:
# tensor([-0.2527-0.2684j, -0.0654-0.0532j, -0.0143-0.0112j, -0.0304-0.0313j,
#         -0.3093-0.3763j], device='cuda:0', dtype=torch.complex128)

# %%
#torch.save(starting_state_tensor, '../saved_tensors/state_tensor_20240328_phaseshift.pt')
#torch.save(starting_transition_tensor, '../saved_tensors/transition_tensor_20240328_phaseshift.pt')
#torch.save(interaction_tensor, '../saved_tensors/interaction_tensor_20240328_phaseshift.pt')
